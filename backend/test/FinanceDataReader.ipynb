# %%
import FinanceDataReader as fdr

# 한국거래소 상장종목 전체
df_krx = fdr.StockListing('KRX-DESC')
df_krx.head()
# Out:
#      Code    Name  Market                                 Sector  \
# 0  060310      3S  KOSDAQ  측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 1  095570  AJ네트웍스   KOSPI                        산업용 기계 및 장비 임대업
# 2  006840   AK홀딩스   KOSPI                                 기타 금융업
# 3  054620     APS  KOSDAQ                                 기타 금융업
# 4  265520   AP시스템  KOSDAQ                          특수 목적용 기계 제조업
#
#               Industry ListingDate SettleMonth     Representative  \
# 0          반도체 웨이퍼 캐리어  2002-04-23         03월                정완영
# 1  렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월                곽정호
# 2                 지주사업  1999-08-11         12월  고준, 채형석 (각자 대표이사)
# 3          인터넷 트래픽 솔루션  2001-12-04         12월                정기로
# 4          디스플레이 제조 장비  2017-04-07         12월         Yoo Ho Sun
#
#                         HomePage Region
# 0           http://www.3sref.com  서울특별시
# 1         http://www.ajnet.co.kr  서울특별시
# 2  http://www.aekyunggroup.co.kr  서울특별시
# ...
