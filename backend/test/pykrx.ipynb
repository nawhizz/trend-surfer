# %%
from pykrx import stock
import pandas as pd
# Out:
# d:\Projects\On\trend-surfer\backend\.venv\Lib\site-packages\pykrx\__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
# 2026-01-12 KOSPI 종목 OHLCV (수정주가)
df = stock.get_market_ohlcv_by_ticker(date="20260112", market="KOSDAQ")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 # 2026-01-12 KOSPI 종목 OHLCV (수정주가)
# ----> 2 df = stock.get_market_ohlcv_by_ticker(date="20260112", market="KOSDAQ")
#       3 print(df.head())
#
# File d:\Projects\On\trend-surfer\backend\.venv\Lib\site-packages\pykrx\stock\stock_api.py:30, in market_valid_check.<locals>._market_valid_check.<locals>.wrapper(*args, **kwargs)
#      28 for v in [x for x in kwargs.values()] + list(args):
#      29     if v in valid_market_list:
# ---> 30         return func(*args, **kwargs)
#      31 print("market 옵션이 올바르지 않습니다.")
#      32 return DataFrame()
#
# File d:\Projects\On\trend-surfer\backend\.venv\Lib\site-packages\pykrx\stock\stock_api.py:290, in get_market_ohlcv_by_ticker(date, market, alternative)
#     287 date = date.replace("-", "")
#     289 df = krx.get_market_ohlcv_by_ticker(date, market)
# ...
